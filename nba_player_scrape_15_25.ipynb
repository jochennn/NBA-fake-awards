# %%
# import libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy import stats

# nba scraper
from nba_api.stats.endpoints import PlayerAwards
from nba_api.stats.endpoints import PlayerGameLog
from nba_api.stats.endpoints import PlayerIndex
from nba_api.stats.endpoints import playercareerstats

# %%
# get nba player data for seasons 2015-2025
# get seasons 2015-2025
seasons = [f'{year}-{str(int(year) + 1)[2:]}' for year in range(2015, 2025)]

player_data = []
for season in seasons:
    player_data.append(PlayerIndex(season=season).get_data_frames()[0])
    # add season to player data
    player_data[-1]['SEASON'] = season

player_data = pd.concat(player_data)

# %%
player_data
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME       PLAYER_SLUG  \
# 0       203919            Adams            Jordan      jordan-adams
# 1      1626146        Alexander             Cliff   cliff-alexander
# 2       200811         Amundson               Lou      lou-amundson
# 3         2365         Andersen             Chris    chris-andersen
# 4       202341         Anderson             James    james-anderson
# ..         ...              ...               ...               ...
# 570    1629027            Young              Trae        trae-young
# 571    1627826            Zubac             Ivica       ivica-zubac
# 572    1641783         da Silva           Tristan  tristan-da-silva
# 573    1628427           Čančar            Vlatko     vlatko-čančar
# 574     203967            Šarić             Dario       dario-šarić
#
#         TEAM_ID  TEAM_SLUG  IS_DEFUNCT   TEAM_CITY      TEAM_NAME  \
# 0    1610612763  grizzlies           0     Memphis      Grizzlies
# 1    1610612757    blazers           0    Portland  Trail Blazers
# 2    1610612752     knicks           0    New York         Knicks
# 3    1610612763  grizzlies           0     Memphis      Grizzlies
# 4    1610612758      kings           0  Sacramento          Kings
# ..          ...        ...         ...         ...            ...
# 570  1610612737      hawks           0     Atlanta          Hawks
# 571  1610612746   clippers           0          LA       Clippers
# 572  1610612753      magic           0     Orlando          Magic
# 573  1610612743    nuggets           0      Denver        Nuggets
# 574  1610612743    nuggets           0      Denver        Nuggets
#
#     TEAM_ABBREVIATION  ... DRAFT_ROUND DRAFT_NUMBER ROSTER_STATUS FROM_YEAR  \
# 0                 MEM  ...         1.0         22.0           1.0      2014
# 1                 POR  ...         NaN          NaN           1.0      2015
# 2                 NYK  ...         NaN          NaN           1.0      2006
# 3                 MEM  ...         NaN          NaN           1.0      2001
# 4                 SAC  ...         1.0         20.0           1.0      2010
# ..                ...  ...         ...          ...           ...       ...
# 570               ATL  ...         1.0          5.0           1.0      2018
# 571               LAC  ...         2.0         32.0           1.0      2016
# 572               ORL  ...         1.0         18.0           1.0      2024
# 573               DEN  ...         2.0         49.0           1.0      2019
# 574               DEN  ...         1.0         12.0           1.0      2016
#
#     TO_YEAR   PTS   REB   AST  STATS_TIMEFRAME   SEASON
# 0      2015   3.5   1.0   1.5           Season  2015-16
# 1      2015   1.3   0.8   0.0           Season  2015-16
# 2      2015   1.8   1.7   0.4           Season  2015-16
# 3      2016   3.9   3.6   0.4           Season  2015-16
# 4      2015   3.5   1.7   0.8           Season  2015-16
# ..      ...   ...   ...   ...              ...      ...
# 570    2024  24.2   3.1  11.6           Season  2024-25
# 571    2024  16.8  12.6   2.7           Season  2024-25
# 572    2024   7.2   3.3   1.5           Season  2024-25
# 573    2024   1.8   2.5   0.7           Season  2024-25
# 574    2024   3.5   3.1   1.4           Season  2024-25
#
# [1703 rows x 27 columns]

# %%
player_data.columns
# Out:
# Index(['PERSON_ID', 'PLAYER_LAST_NAME', 'PLAYER_FIRST_NAME', 'PLAYER_SLUG',
#        'TEAM_ID', 'TEAM_SLUG', 'IS_DEFUNCT', 'TEAM_CITY', 'TEAM_NAME',
#        'TEAM_ABBREVIATION', 'JERSEY_NUMBER', 'POSITION', 'HEIGHT', 'WEIGHT',
#        'COLLEGE', 'COUNTRY', 'DRAFT_YEAR', 'DRAFT_ROUND', 'DRAFT_NUMBER',
#        'ROSTER_STATUS', 'FROM_YEAR', 'TO_YEAR', 'PTS', 'REB', 'AST',
#        'STATS_TIMEFRAME', 'SEASON'],
#       dtype='object')

# %%
# Create empty list to store career stats
season_stats = []

# get all unique player ids
unique_player_ids = player_data['PERSON_ID'].unique()

# Loop through each player ID and get their career stats
for player_id in unique_player_ids:
    try:
        # Get career stats for player
        player_stats = playercareerstats.PlayerCareerStats(player_id=player_id)
        # Get the data frame from the response
        stats_df = player_stats.get_data_frames()[0]
        # Append to list
        season_stats.append(stats_df)
    except:
        print(f"Could not get stats for player ID {player_id}")
        continue

# Combine all stats into single dataframe if list is not empty
if season_stats:
    season_stats = pd.concat(season_stats)
else:
    print("No career stats were retrieved")
# Out:
# Could not get stats for player ID 1628778
# Could not get stats for player ID 204222
# Could not get stats for player ID 1628391
# Could not get stats for player ID 200746
# Could not get stats for player ID 2546
# Could not get stats for player ID 1627853
# Could not get stats for player ID 201571
# Could not get stats for player ID 1630555
# Could not get stats for player ID 1627760
# Could not get stats for player ID 1628238
# Could not get stats for player ID 203145
# Could not get stats for player ID 202357
# Could not get stats for player ID 202339
# Could not get stats for player ID 1629833
# Could not get stats for player ID 1630195
# Could not get stats for player ID 1629067
# Could not get stats for player ID 202340
# Could not get stats for player ID 1629649
# Could not get stats for player ID 1629717
# Could not get stats for player ID 1628425
# Could not get stats for player ID 1630602
# Could not get stats for player ID 1629783
# Could not get stats for player ID 203504
# Could not get stats for player ID 1629719
# Could not get stats for player ID 1630267
# Could not get stats for player ID 1629962
# Could not get stats for player ID 1626161
# Could not get stats for player ID 1629958
# Could not get stats for player ID 1629185
# Could not get stats for player ID 1627737
# Could not get stats for player ID 1629109
# Could not get stats for player ID 1629076
# Could not get stats for player ID 1630536
# Could not get stats for player ID 1627822
# Could not get stats for player ID 202326
# Could not get stats for player ID 1629633
# Could not get stats for player ID 1629600
# Could not get stats for player ID 202334
# Could not get stats for player ID 1629602
# Could not get stats for player ID 1630693
# Could not get stats for player ID 1629035
# Could not get stats for player ID 1630306
# Could not get stats for player ID 1629604
# Could not get stats for player ID 201961
# Could not get stats for player ID 202324
# Could not get stats for player ID 1630238
# Could not get stats for player ID 1627854
# Could not get stats for player ID 1630758
# Could not get stats for player ID 1628982
# Could not get stats for player ID 1629164
# Could not get stats for player ID 1629755
# Could not get stats for player ID 1629788
# Could not get stats for player ID 203090
# Could not get stats for player ID 1629607
# Could not get stats for player ID 1630565
# Could not get stats for player ID 1627823
# Could not get stats for player ID 203918
FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   season_stats = pd.concat(season_stats)

# %%
season_stats
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203919   2014-15        00  1610612763               MEM        20.0
# 1     203919   2015-16        00  1610612763               MEM        21.0
# 0    1626146   2015-16        00  1610612757               POR        20.0
# 0     200811   2006-07        00  1610612762               UTA        24.0
# 1     200811   2006-07        00  1610612755               PHI        24.0
# ..       ...       ...       ...         ...               ...         ...
# 7     203967   2022-23        00  1610612756               PHX        29.0
# 8     203967   2022-23        00  1610612760               OKC        29.0
# 9     203967   2022-23        00           0               TOT        29.0
# 10    203967   2023-24        00  1610612744               GSW        30.0
# 11    203967   2024-25        00  1610612743               DEN        31.0
#
#     GP  GS     MIN  FGM  ... FT_PCT  OREB DREB  REB  AST STL BLK  TOV   PF  \
# 0   30   0   248.0   35  ...  0.609     9   19   28   16  16   7   14   24
# 1    2   0    15.0    2  ...  0.600     0    2    2    3   3   0    2    2
# 0    8   0    36.0    5  ...  0.000     2    4    6    0   1   2    1    1
# 0    1   0     2.0    0  ...  0.000     0    0    0    0   0   0    0    0
# 1   10   0    87.0    6  ...  0.400    13   15   28    1   1   8    5   15
# ..  ..  ..     ...  ...  ...    ...   ...  ...  ...  ...  ..  ..  ...  ...
# 7   37  12   533.0   76  ...  0.818    39  103  142   57  13   5   36   69
# 8   20   0   273.0   51  ...  0.844    14   51   65   17   7   2   19   30
# 9   57  12   806.0  127  ...  0.829    53  154  207   74  20   7   55   99
# 10  64   9  1098.0  181  ...  0.849    73  210  283  144  31  10   78  112
# 11  16   4   210.0   21  ...  0.700    14   36   50   23   7   1   15   19
#
#     PTS
# 0    94
# 1     7
# 0    10
# 0     0
# 1    16
# ..  ...
# 7   215
# 8   147
# 9   362
# 10  515
# 11   56
#
# [7479 rows x 27 columns]

# %%
player_data_totals=player_data.merge(season_stats, left_on='PERSON_ID', right_on='PLAYER_ID', how='right')
player_data_totals
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME      PLAYER_SLUG  \
# 0       203919            Adams            Jordan     jordan-adams
# 1       203919            Adams            Jordan     jordan-adams
# 2      1626146        Alexander             Cliff  cliff-alexander
# 3       200811         Amundson               Lou     lou-amundson
# 4       200811         Amundson               Lou     lou-amundson
# ...        ...              ...               ...              ...
# 8876    203967            Šarić             Dario      dario-šarić
# 8877    203967            Šarić             Dario      dario-šarić
# 8878    203967            Šarić             Dario      dario-šarić
# 8879    203967            Šarić             Dario      dario-šarić
# 8880    203967            Šarić             Dario      dario-šarić
#
#        TEAM_ID_x  TEAM_SLUG  IS_DEFUNCT TEAM_CITY      TEAM_NAME  \
# 0     1610612763  grizzlies           0   Memphis      Grizzlies
# 1     1610612763  grizzlies           0   Memphis      Grizzlies
# 2     1610612757    blazers           0  Portland  Trail Blazers
# 3     1610612752     knicks           0  New York         Knicks
# 4     1610612752     knicks           0  New York         Knicks
# ...          ...        ...         ...       ...            ...
# 8876  1610612743    nuggets           0    Denver        Nuggets
# 8877  1610612743    nuggets           0    Denver        Nuggets
# 8878  1610612743    nuggets           0    Denver        Nuggets
# 8879  1610612743    nuggets           0    Denver        Nuggets
# 8880  1610612743    nuggets           0    Denver        Nuggets
#
#      TEAM_ABBREVIATION_x  ... FT_PCT OREB DREB REB_y AST_y STL  BLK  TOV   PF  \
# 0                    MEM  ...  0.609    9   19    28    16  16    7   14   24
# 1                    MEM  ...  0.600    0    2     2     3   3    0    2    2
# 2                    POR  ...  0.000    2    4     6     0   1    2    1    1
# 3                    NYK  ...  0.000    0    0     0     0   0    0    0    0
# 4                    NYK  ...  0.400   13   15    28     1   1    8    5   15
# ...                  ...  ...    ...  ...  ...   ...   ...  ..  ...  ...  ...
# 8876                 DEN  ...  0.818   39  103   142    57  13    5   36   69
# 8877                 DEN  ...  0.844   14   51    65    17   7    2   19   30
# 8878                 DEN  ...  0.829   53  154   207    74  20    7   55   99
# 8879                 DEN  ...  0.849   73  210   283   144  31   10   78  112
# 8880                 DEN  ...  0.700   14   36    50    23   7    1   15   19
#
#       PTS_y
# 0        94
# 1         7
# 2        10
# 3         0
# 4        16
# ...     ...
# 8876    215
# 8877    147
# 8878    362
# 8879    515
# 8880     56
#
# [8881 rows x 54 columns]

# %%
player_data_totals.columns
# Out:
# Index(['PERSON_ID', 'PLAYER_LAST_NAME', 'PLAYER_FIRST_NAME', 'PLAYER_SLUG',
#        'TEAM_ID_x', 'TEAM_SLUG', 'IS_DEFUNCT', 'TEAM_CITY', 'TEAM_NAME',
#        'TEAM_ABBREVIATION_x', 'JERSEY_NUMBER', 'POSITION', 'HEIGHT', 'WEIGHT',
#        'COLLEGE', 'COUNTRY', 'DRAFT_YEAR', 'DRAFT_ROUND', 'DRAFT_NUMBER',
#        'ROSTER_STATUS', 'FROM_YEAR', 'TO_YEAR', 'PTS_x', 'REB_x', 'AST_x',
#        'STATS_TIMEFRAME', 'SEASON', 'PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID',
#        'TEAM_ID_y', 'TEAM_ABBREVIATION_y', 'PLAYER_AGE', 'GP', 'GS', 'MIN',
#        'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB_y', 'AST_y', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS_y'],
#       dtype='object')

# %%
player_data_totals=player_data_totals.drop(columns=['LEAGUE_ID', 'TEAM_ID_x','TEAM_ABBREVIATION_x','PTS_x','AST_x','REB_x'])
player_data_totals
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME      PLAYER_SLUG  TEAM_SLUG  \
# 0       203919            Adams            Jordan     jordan-adams  grizzlies
# 1       203919            Adams            Jordan     jordan-adams  grizzlies
# 2      1626146        Alexander             Cliff  cliff-alexander    blazers
# 3       200811         Amundson               Lou     lou-amundson     knicks
# 4       200811         Amundson               Lou     lou-amundson     knicks
# ...        ...              ...               ...              ...        ...
# 8876    203967            Šarić             Dario      dario-šarić    nuggets
# 8877    203967            Šarić             Dario      dario-šarić    nuggets
# 8878    203967            Šarić             Dario      dario-šarić    nuggets
# 8879    203967            Šarić             Dario      dario-šarić    nuggets
# 8880    203967            Šarić             Dario      dario-šarić    nuggets
#
#       IS_DEFUNCT TEAM_CITY      TEAM_NAME JERSEY_NUMBER POSITION  ... FT_PCT  \
# 0              0   Memphis      Grizzlies             3        G  ...  0.609
# 1              0   Memphis      Grizzlies             3        G  ...  0.600
# 2              0  Portland  Trail Blazers            34        F  ...  0.000
# 3              0  New York         Knicks            17        F  ...  0.000
# 4              0  New York         Knicks            17        F  ...  0.400
# ...          ...       ...            ...           ...      ...  ...    ...
# 8876           0    Denver        Nuggets             9      F-C  ...  0.818
# 8877           0    Denver        Nuggets             9      F-C  ...  0.844
# 8878           0    Denver        Nuggets             9      F-C  ...  0.829
# 8879           0    Denver        Nuggets             9      F-C  ...  0.849
# 8880           0    Denver        Nuggets             9      F-C  ...  0.700
#
#      OREB DREB REB_y  AST_y  STL  BLK  TOV   PF PTS_y
# 0       9   19    28     16   16    7   14   24    94
# 1       0    2     2      3    3    0    2    2     7
# 2       2    4     6      0    1    2    1    1    10
# 3       0    0     0      0    0    0    0    0     0
# 4      13   15    28      1    1    8    5   15    16
# ...   ...  ...   ...    ...  ...  ...  ...  ...   ...
# 8876   39  103   142     57   13    5   36   69   215
# 8877   14   51    65     17    7    2   19   30   147
# 8878   53  154   207     74   20    7   55   99   362
# 8879   73  210   283    144   31   10   78  112   515
# 8880   14   36    50     23    7    1   15   19    56
#
# [8881 rows x 48 columns]

# %%
# show nans
player_data_totals.isna().sum()
# Out:
# PERSON_ID                 0
# PLAYER_LAST_NAME          0
# PLAYER_FIRST_NAME         0
# PLAYER_SLUG               0
# TEAM_SLUG              1625
# IS_DEFUNCT                0
# TEAM_CITY              1625
# TEAM_NAME              1625
# JERSEY_NUMBER          1630
# POSITION                  0
# HEIGHT                    0
# WEIGHT                    1
# COLLEGE                   0
# COUNTRY                   0
# DRAFT_YEAR             1666
# DRAFT_ROUND            1775
# DRAFT_NUMBER           1786
# ROSTER_STATUS          1625
# FROM_YEAR                 0
# TO_YEAR                   0
# STATS_TIMEFRAME           0
# SEASON                    0
# PLAYER_ID                 0
# SEASON_ID                 0
# TEAM_ID_y                 0
# TEAM_ABBREVIATION_y       0
# PLAYER_AGE                0
# GP                        0
# GS                        0
# MIN                       0
# FGM                       0
# FGA                       0
# FG_PCT                    0
# FG3M                      0
# FG3A                      0
# FG3_PCT                   0
# FTM                       0
# FTA                       0
# FT_PCT                    0
# OREB                      0
# DREB                      0
# REB_y                     0
# AST_y                     0
# STL                       0
# BLK                       0
# TOV                       0
# PF                        0
# PTS_y                     0
# dtype: int64

# %%
player_data_totals.columns
# Out:
# Index(['PERSON_ID', 'PLAYER_LAST_NAME', 'PLAYER_FIRST_NAME', 'PLAYER_SLUG',
#        'TEAM_SLUG', 'IS_DEFUNCT', 'TEAM_CITY', 'TEAM_NAME', 'JERSEY_NUMBER',
#        'POSITION', 'HEIGHT', 'WEIGHT', 'COLLEGE', 'COUNTRY', 'DRAFT_YEAR',
#        'DRAFT_ROUND', 'DRAFT_NUMBER', 'ROSTER_STATUS', 'FROM_YEAR', 'TO_YEAR',
#        'STATS_TIMEFRAME', 'SEASON', 'PLAYER_ID', 'SEASON_ID', 'TEAM_ID_y',
#        'TEAM_ABBREVIATION_y', 'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA',
#        'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB',
#        'DREB', 'REB_y', 'AST_y', 'STL', 'BLK', 'TOV', 'PF', 'PTS_y'],
#       dtype='object')

# %%
# remove the suffix to columns with _y
player_data_totals.columns = player_data_totals.columns.str.rstrip('_y')
player_data_totals.columns
# Out:
# Index(['PERSON_ID', 'PLAYER_LAST_NAME', 'PLAYER_FIRST_NAME', 'PLAYER_SLUG',
#        'TEAM_SLUG', 'IS_DEFUNCT', 'TEAM_CITY', 'TEAM_NAME', 'JERSEY_NUMBER',
#        'POSITION', 'HEIGHT', 'WEIGHT', 'COLLEGE', 'COUNTRY', 'DRAFT_YEAR',
#        'DRAFT_ROUND', 'DRAFT_NUMBER', 'ROSTER_STATUS', 'FROM_YEAR', 'TO_YEAR',
#        'STATS_TIMEFRAME', 'SEASON', 'PLAYER_ID', 'SEASON_ID', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA',
#        'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
# show nan summary
player_data_totals.isna().sum()
# Out:
# PERSON_ID               0
# PLAYER_LAST_NAME        0
# PLAYER_FIRST_NAME       0
# PLAYER_SLUG             0
# TEAM_SLUG            1625
# IS_DEFUNCT              0
# TEAM_CITY            1625
# TEAM_NAME            1625
# JERSEY_NUMBER        1630
# POSITION                0
# HEIGHT                  0
# WEIGHT                  1
# COLLEGE                 0
# COUNTRY                 0
# DRAFT_YEAR           1666
# DRAFT_ROUND          1775
# DRAFT_NUMBER         1786
# ROSTER_STATUS        1625
# FROM_YEAR               0
# TO_YEAR                 0
# STATS_TIMEFRAME         0
# SEASON                  0
# PLAYER_ID               0
# SEASON_ID               0
# TEAM_ID                 0
# TEAM_ABBREVIATION       0
# PLAYER_AGE              0
# GP                      0
# GS                      0
# MIN                     0
# FGM                     0
# FGA                     0
# FG_PCT                  0
# FG3M                    0
# FG3A                    0
# FG3_PCT                 0
# FTM                     0
# FTA                     0
# FT_PCT                  0
# OREB                    0
# DREB                    0
# REB                     0
# AST                     0
# STL                     0
# BLK                     0
# TOV                     0
# PF                      0
# PTS                     0
# dtype: int64

# %%
# remove players where team slug is nan
player_data_totals=player_data_totals[player_data_totals['TEAM_SLUG'].notna()]
player_data_totals
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME      PLAYER_SLUG  TEAM_SLUG  \
# 0       203919            Adams            Jordan     jordan-adams  grizzlies
# 1       203919            Adams            Jordan     jordan-adams  grizzlies
# 2      1626146        Alexander             Cliff  cliff-alexander    blazers
# 3       200811         Amundson               Lou     lou-amundson     knicks
# 4       200811         Amundson               Lou     lou-amundson     knicks
# ...        ...              ...               ...              ...        ...
# 8876    203967            Šarić             Dario      dario-šarić    nuggets
# 8877    203967            Šarić             Dario      dario-šarić    nuggets
# 8878    203967            Šarić             Dario      dario-šarić    nuggets
# 8879    203967            Šarić             Dario      dario-šarić    nuggets
# 8880    203967            Šarić             Dario      dario-šarić    nuggets
#
#       IS_DEFUNCT TEAM_CITY      TEAM_NAME JERSEY_NUMBER POSITION  ... FT_PCT  \
# 0              0   Memphis      Grizzlies             3        G  ...  0.609
# 1              0   Memphis      Grizzlies             3        G  ...  0.600
# 2              0  Portland  Trail Blazers            34        F  ...  0.000
# 3              0  New York         Knicks            17        F  ...  0.000
# 4              0  New York         Knicks            17        F  ...  0.400
# ...          ...       ...            ...           ...      ...  ...    ...
# 8876           0    Denver        Nuggets             9      F-C  ...  0.818
# 8877           0    Denver        Nuggets             9      F-C  ...  0.844
# 8878           0    Denver        Nuggets             9      F-C  ...  0.829
# 8879           0    Denver        Nuggets             9      F-C  ...  0.849
# 8880           0    Denver        Nuggets             9      F-C  ...  0.700
#
#      OREB DREB  REB  AST  STL  BLK  TOV   PF  PTS
# 0       9   19   28   16   16    7   14   24   94
# 1       0    2    2    3    3    0    2    2    7
# 2       2    4    6    0    1    2    1    1   10
# 3       0    0    0    0    0    0    0    0    0
# 4      13   15   28    1    1    8    5   15   16
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...
# 8876   39  103  142   57   13    5   36   69  215
# 8877   14   51   65   17    7    2   19   30  147
# 8878   53  154  207   74   20    7   55   99  362
# 8879   73  210  283  144   31   10   78  112  515
# 8880   14   36   50   23    7    1   15   19   56
#
# [7256 rows x 48 columns]

# %%
# show summary of nan
player_data_totals.isna().sum()
# Out:
# PERSON_ID               0
# PLAYER_LAST_NAME        0
# PLAYER_FIRST_NAME       0
# PLAYER_SLUG             0
# TEAM_SLUG               0
# IS_DEFUNCT              0
# TEAM_CITY               0
# TEAM_NAME               0
# JERSEY_NUMBER           5
# POSITION                0
# HEIGHT                  0
# WEIGHT                  1
# COLLEGE                 0
# COUNTRY                 0
# DRAFT_YEAR           1240
# DRAFT_ROUND          1303
# DRAFT_NUMBER         1313
# ROSTER_STATUS           0
# FROM_YEAR               0
# TO_YEAR                 0
# STATS_TIMEFRAME         0
# SEASON                  0
# PLAYER_ID               0
# SEASON_ID               0
# TEAM_ID                 0
# TEAM_ABBREVIATION       0
# PLAYER_AGE              0
# GP                      0
# GS                      0
# MIN                     0
# FGM                     0
# FGA                     0
# FG_PCT                  0
# FG3M                    0
# FG3A                    0
# FG3_PCT                 0
# FTM                     0
# FTA                     0
# FT_PCT                  0
# OREB                    0
# DREB                    0
# REB                     0
# AST                     0
# STL                     0
# BLK                     0
# TOV                     0
# PF                      0
# PTS                     0
# dtype: int64

# %%
# remove players where JERSEY_NUMBER is nan
player_data_totals=player_data_totals[player_data_totals['JERSEY_NUMBER'].notna()]

# show summary of nan
player_data_totals.isna().sum()
# Out:
# PERSON_ID               0
# PLAYER_LAST_NAME        0
# PLAYER_FIRST_NAME       0
# PLAYER_SLUG             0
# TEAM_SLUG               0
# IS_DEFUNCT              0
# TEAM_CITY               0
# TEAM_NAME               0
# JERSEY_NUMBER           0
# POSITION                0
# HEIGHT                  0
# WEIGHT                  1
# COLLEGE                 0
# COUNTRY                 0
# DRAFT_YEAR           1235
# DRAFT_ROUND          1298
# DRAFT_NUMBER         1308
# ROSTER_STATUS           0
# FROM_YEAR               0
# TO_YEAR                 0
# STATS_TIMEFRAME         0
# SEASON                  0
# PLAYER_ID               0
# SEASON_ID               0
# TEAM_ID                 0
# TEAM_ABBREVIATION       0
# PLAYER_AGE              0
# GP                      0
# GS                      0
# MIN                     0
# FGM                     0
# FGA                     0
# FG_PCT                  0
# FG3M                    0
# FG3A                    0
# FG3_PCT                 0
# FTM                     0
# FTA                     0
# FT_PCT                  0
# OREB                    0
# DREB                    0
# REB                     0
# AST                     0
# STL                     0
# BLK                     0
# TOV                     0
# PF                      0
# PTS                     0
# dtype: int64

# %%
# remove players where weight is nan
player_data_totals=player_data_totals[player_data_totals['WEIGHT'].notna()]

# %%
# show summary of nan
player_data_totals.isna().sum()
# Out:
# PERSON_ID               0
# PLAYER_LAST_NAME        0
# PLAYER_FIRST_NAME       0
# PLAYER_SLUG             0
# TEAM_SLUG               0
# IS_DEFUNCT              0
# TEAM_CITY               0
# TEAM_NAME               0
# JERSEY_NUMBER           0
# POSITION                0
# HEIGHT                  0
# WEIGHT                  0
# COLLEGE                 0
# COUNTRY                 0
# DRAFT_YEAR           1234
# DRAFT_ROUND          1297
# DRAFT_NUMBER         1307
# ROSTER_STATUS           0
# FROM_YEAR               0
# TO_YEAR                 0
# STATS_TIMEFRAME         0
# SEASON                  0
# PLAYER_ID               0
# SEASON_ID               0
# TEAM_ID                 0
# TEAM_ABBREVIATION       0
# PLAYER_AGE              0
# GP                      0
# GS                      0
# MIN                     0
# FGM                     0
# FGA                     0
# FG_PCT                  0
# FG3M                    0
# FG3A                    0
# FG3_PCT                 0
# FTM                     0
# FTA                     0
# FT_PCT                  0
# OREB                    0
# DREB                    0
# REB                     0
# AST                     0
# STL                     0
# BLK                     0
# TOV                     0
# PF                      0
# PTS                     0
# dtype: int64

# %%
# show players where DRAFT_YEAR is nan
player_data_totals[player_data_totals['DRAFT_YEAR'].isna()]
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME       PLAYER_SLUG TEAM_SLUG  \
# 2      1626146        Alexander             Cliff   cliff-alexander   blazers
# 3       200811         Amundson               Lou      lou-amundson    knicks
# 4       200811         Amundson               Lou      lou-amundson    knicks
# 5       200811         Amundson               Lou      lou-amundson    knicks
# 6       200811         Amundson               Lou      lou-amundson    knicks
# ...        ...              ...               ...               ...       ...
# 8789   1629026         Williams           Kenrich  kenrich-williams   thunder
# 8793   1631466         Williams              Nate     nate-williams   rockets
# 8794   1631466         Williams              Nate     nate-williams   rockets
# 8795   1631466         Williams              Nate     nate-williams   rockets
# 8844   1642443            Young            Jahmir      jahmir-young     bulls
#
#       IS_DEFUNCT      TEAM_CITY      TEAM_NAME JERSEY_NUMBER POSITION  ...  \
# 2              0       Portland  Trail Blazers            34        F  ...
# 3              0       New York         Knicks            17        F  ...
# 4              0       New York         Knicks            17        F  ...
# 5              0       New York         Knicks            17        F  ...
# 6              0       New York         Knicks            17        F  ...
# ...          ...            ...            ...           ...      ...  ...
# 8789           0  Oklahoma City        Thunder            34      G-F  ...
# 8793           0        Houston        Rockets            19        G  ...
# 8794           0        Houston        Rockets            19        G  ...
# 8795           0        Houston        Rockets            19        G  ...
# 8844           0        Chicago          Bulls            11        G  ...
#
#      FT_PCT OREB DREB  REB  AST  STL  BLK  TOV   PF  PTS
# 2     0.000    2    4    6    0    1    2    1    1   10
# 3     0.000    0    0    0    0    0    0    0    0    0
# 4     0.400   13   15   28    1    1    8    5   15   16
# 5     0.400   13   15   28    1    1    8    5   15   16
# 6     0.286    7    5   12    0    1    1    2   13   18
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 8789  0.718   65  176  241   97   43   10   39  110  436
# 8793  0.667   10    5   15   10    3    2    4   13   53
# 8794  0.538   12   11   23    7    4    1    4   10   63
# 8795  0.625    5    8   13    9    8    4   14   16   65
# 8844  1.000    1    2    3    6    0    0    1    2   11
#
# [1234 rows x 48 columns]

# %%
# remove players with unknown draft year
player_data_totals=player_data_totals[player_data_totals['DRAFT_YEAR'].notna()]

# show summary of nan
player_data_totals.isna().sum()
# Out:
# PERSON_ID             0
# PLAYER_LAST_NAME      0
# PLAYER_FIRST_NAME     0
# PLAYER_SLUG           0
# TEAM_SLUG             0
# IS_DEFUNCT            0
# TEAM_CITY             0
# TEAM_NAME             0
# JERSEY_NUMBER         0
# POSITION              0
# HEIGHT                0
# WEIGHT                0
# COLLEGE               0
# COUNTRY               0
# DRAFT_YEAR            0
# DRAFT_ROUND          63
# DRAFT_NUMBER         73
# ROSTER_STATUS         0
# FROM_YEAR             0
# TO_YEAR               0
# STATS_TIMEFRAME       0
# SEASON                0
# PLAYER_ID             0
# SEASON_ID             0
# TEAM_ID               0
# TEAM_ABBREVIATION     0
# PLAYER_AGE            0
# GP                    0
# GS                    0
# MIN                   0
# FGM                   0
# FGA                   0
# FG_PCT                0
# FG3M                  0
# FG3A                  0
# FG3_PCT               0
# FTM                   0
# FTA                   0
# FT_PCT                0
# OREB                  0
# DREB                  0
# REB                   0
# AST                   0
# STL                   0
# BLK                   0
# TOV                   0
# PF                    0
# PTS                   0
# dtype: int64

# %%
# change players where DRAFT_ROUND is nan to 'Undrafted'
player_data_totals.loc[player_data_totals['DRAFT_ROUND'].isna(), 'DRAFT_ROUND'] = 'Undrafted'

# do the same for DRAFT_NUMBER
player_data_totals.loc[player_data_totals['DRAFT_NUMBER'].isna(), 'DRAFT_NUMBER'] = 'Undrafted'

player_data_totals
# Out:
# C:\Users\17782\AppData\Local\Temp\ipykernel_9376\508266427.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Undrafted' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   player_data_totals.loc[player_data_totals['DRAFT_ROUND'].isna(), 'DRAFT_ROUND'] = 'Undrafted'
# C:\Users\17782\AppData\Local\Temp\ipykernel_9376\508266427.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Undrafted' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   player_data_totals.loc[player_data_totals['DRAFT_NUMBER'].isna(), 'DRAFT_NUMBER'] = 'Undrafted'
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME     PLAYER_SLUG  TEAM_SLUG  \
# 0       203919            Adams            Jordan    jordan-adams  grizzlies
# 1       203919            Adams            Jordan    jordan-adams  grizzlies
# 56      202341         Anderson             James  james-anderson      kings
# 57      202341         Anderson             James  james-anderson      kings
# 58      202341         Anderson             James  james-anderson      kings
# ...        ...              ...               ...             ...        ...
# 8876    203967            Šarić             Dario     dario-šarić    nuggets
# 8877    203967            Šarić             Dario     dario-šarić    nuggets
# 8878    203967            Šarić             Dario     dario-šarić    nuggets
# 8879    203967            Šarić             Dario     dario-šarić    nuggets
# 8880    203967            Šarić             Dario     dario-šarić    nuggets
#
#       IS_DEFUNCT   TEAM_CITY  TEAM_NAME JERSEY_NUMBER POSITION  ... FT_PCT  \
# 0              0     Memphis  Grizzlies             3        G  ...  0.609
# 1              0     Memphis  Grizzlies             3        G  ...  0.600
# 56             0  Sacramento      Kings             5      G-F  ...  0.778
# 57             0  Sacramento      Kings             5      G-F  ...  0.750
# 58             0  Sacramento      Kings             5      G-F  ...  0.778
# ...          ...         ...        ...           ...      ...  ...    ...
# 8876           0      Denver    Nuggets             9      F-C  ...  0.818
# 8877           0      Denver    Nuggets             9      F-C  ...  0.844
# 8878           0      Denver    Nuggets             9      F-C  ...  0.829
# 8879           0      Denver    Nuggets             9      F-C  ...  0.849
# 8880           0      Denver    Nuggets             9      F-C  ...  0.700
#
#      OREB DREB  REB  AST STL BLK  TOV   PF  PTS
# 0       9   19   28   16  16   7   14   24   94
# 1       0    2    2    3   3   0    2    2    7
# 56      2   21   23   18   3   6   13   24   94
# 57     16   63   79   41   8   2   30   35  190
# 58      3   11   14    9   3   2    7    7   34
# ...   ...  ...  ...  ...  ..  ..  ...  ...  ...
# 8876   39  103  142   57  13   5   36   69  215
# 8877   14   51   65   17   7   2   19   30  147
# 8878   53  154  207   74  20   7   55   99  362
# 8879   73  210  283  144  31  10   78  112  515
# 8880   14   36   50   23   7   1   15   19   56
#
# [6016 rows x 48 columns]

# %%
# show all columns
player_data_totals.columns
# Out:
# Index(['PERSON_ID', 'PLAYER_LAST_NAME', 'PLAYER_FIRST_NAME', 'PLAYER_SLUG',
#        'TEAM_SLUG', 'IS_DEFUNCT', 'TEAM_CITY', 'TEAM_NAME', 'JERSEY_NUMBER',
#        'POSITION', 'HEIGHT', 'WEIGHT', 'COLLEGE', 'COUNTRY', 'DRAFT_YEAR',
#        'DRAFT_ROUND', 'DRAFT_NUMBER', 'ROSTER_STATUS', 'FROM_YEAR', 'TO_YEAR',
#        'STATS_TIMEFRAME', 'SEASON', 'PLAYER_ID', 'SEASON_ID', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA',
#        'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
# get season averages
player_data_totals['PPG'] = player_data_totals['PTS'] / player_data_totals['GP']
player_data_totals['RPG'] = player_data_totals['REB'] / player_data_totals['GP']
player_data_totals['APG'] = player_data_totals['AST'] / player_data_totals['GP']
player_data_totals['SPG'] = player_data_totals['STL'] / player_data_totals['GP']
player_data_totals['BPG'] = player_data_totals['BLK'] / player_data_totals['GP']
player_data_totals['TOVPG'] = player_data_totals['TOV'] / player_data_totals['GP']
player_data_totals['MINPG'] = player_data_totals['MIN'] / player_data_totals['GP']
player_data_totals['OREBPG '] = player_data_totals['OREB'] / player_data_totals['GP']
player_data_totals['DREBPG'] = player_data_totals['DREB'] / player_data_totals['GP']
player_data_totals['STLPG   '] = player_data_totals['STL'] / player_data_totals['GP']
player_data_totals['BLKPG'] = player_data_totals['BLK'] / player_data_totals['GP']
player_data_totals['TOVPG'] = player_data_totals['TOV'] / player_data_totals['GP']
player_data_totals['PFPG'] = player_data_totals['PF'] / player_data_totals['GP']

# %%
# read to a csv
player_data_totals.to_csv('./data/nba_player_data_15_25.csv', index=False)
